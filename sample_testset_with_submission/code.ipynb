# %%
import pandas as pd

# %%
gold = pd.read_csv('sample_test_set_gold.csv')
gold
# Out:
#       ID  label
# 0      0      0
# 1      1      6
# 2      2      0
# 3      3      4
# 4      4      6
# ..   ...    ...
# 177  177     14
# 178  178      6
# 179  179      0
# 180  180      6
# 181  181      2
#
# [182 rows x 2 columns]

# %%
test = pd.read_csv('test.csv')
test
# Out:
#       ID  label
# 0      0      0
# 1      1      6
# 2      2      0
# 3      3      4
# 4      4      6
# ..   ...    ...
# 177  177     14
# 178  178      6
# 179  179      0
# 180  180      6
# 181  181      2
#
# [182 rows x 2 columns]

# %%
sum(test.label == gold.label) / gold.shape[0] * 100
# Out:
# 99.45054945054946

# %%
gold.shape[0]
# Out:
# 182
